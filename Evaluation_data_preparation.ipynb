# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...

# %%
import pandas as pd

df = pd.read_csv("finepdfs_new_Deva_train.csv")

df.head().to_clipboard()

# %%
df.head()
# Out:
#                                                 text  \
# 0  ‌​\n\n.. shrI vallyaShTottarashatanAmAvaliH .....
# 1  Cocking(Parish(Council(\n\n(\n\nMinutes(of(Mee...
# 2  .\n\nDocument Information\n\nText title : gaNe...
# 3  ्ल\n\nु\n\nजिल्ला :रुक ु म (पजिम भाग) गा जि स/...
# 4  萃 यागी,ꈅीमती शीला\n\nबहु जन समाज पाट嫽ᘂ\n\n­\n\...
#
#                                                 id             dump  \
# 0  <urn:uuid:3846e8d0-2e10-45e7-8c0c-3386cfb315b3>  CC-MAIN-2017-47
# 1  <urn:uuid:bded732a-1e77-4f15-906b-647a4d17529c>  CC-MAIN-2019-04
# 2  <urn:uuid:a5fdbc1a-7390-47b1-8074-10c450976bc9>  CC-MAIN-2017-39
# 3  <urn:uuid:519d0ca6-4e2e-4aee-8fcc-de667e29d0f7>  CC-MAIN-2020-45
# 4  <urn:uuid:dc62579d-6ff5-4743-95e7-6f0e639482f9>  CC-MAIN-2017-39
#
#                                                  url  \
# 0  https://sanskritdocuments.org/doc_devii/subra1...
# 1  https://cocking.org/images/cpc-documents/2014-...
# 2  https://sanskritdocuments.org/doc_ganesha/gane...
# ...

# %%
def remove_newline(text):
    return re.sub(r"\n", " ", text)

# %%
import re
df["text"] = df["text"].apply(remove_newline)
#df["text"] = df["text"].str.replace("\n", " ", regex=False)

df.head()
# Out:
#                                                 text  \
# 0  ‌​  .. shrI vallyaShTottarashatanAmAvaliH ..  ...
# 1  Cocking(Parish(Council(  (  Minutes(of(Meeting...
# 2  .  Document Information  Text title : gaNesha ...
# 3  ्ल  ु  जिल्ला :रुक ु म (पजिम भाग) गा जि स/न.पा...
# 4  萃 यागी,ꈅीमती शीला  बहु जन समाज पाट嫽ᘂ  ­  耂नवा᷽...
#
#                                                 id             dump  \
# 0  <urn:uuid:3846e8d0-2e10-45e7-8c0c-3386cfb315b3>  CC-MAIN-2017-47
# 1  <urn:uuid:bded732a-1e77-4f15-906b-647a4d17529c>  CC-MAIN-2019-04
# 2  <urn:uuid:a5fdbc1a-7390-47b1-8074-10c450976bc9>  CC-MAIN-2017-39
# 3  <urn:uuid:519d0ca6-4e2e-4aee-8fcc-de667e29d0f7>  CC-MAIN-2020-45
# 4  <urn:uuid:dc62579d-6ff5-4743-95e7-6f0e639482f9>  CC-MAIN-2017-39
#
#                                                  url  \
# 0  https://sanskritdocuments.org/doc_devii/subra1...
# 1  https://cocking.org/images/cpc-documents/2014-...
# 2  https://sanskritdocuments.org/doc_ganesha/gane...
# ...

# %%
df.to_csv("new_Deva.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1661 entries, 0 to 1660
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   text                    1661 non-null   object
#  1   id                      1661 non-null   object
#  2   dump                    1661 non-null   object
#  3   url                     1661 non-null   object
#  4   date                    1661 non-null   object
#  5   file_path               1661 non-null   object
#  6   offset                  1661 non-null   int64
#  7   token_count             1661 non-null   int64
#  8   language                1661 non-null   object
#  9   page_average_lid        1661 non-null   object
#  10  page_average_lid_score  1661 non-null   float64
#  11  full_doc_lid            1661 non-null   object
#  12  full_doc_lid_score      1661 non-null   float64
#  13  per_page_languages      1661 non-null   object
# ...
